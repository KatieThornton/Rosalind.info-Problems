# %%
def reverse_complement(dna):
    mapping = str.maketrans("ATCG" , "TAGC")
    complement = dna.translate(mapping)
    return complement[::-1]

# %%
input = '...'
print(reverse_complement(input))
# Out:
# ...
