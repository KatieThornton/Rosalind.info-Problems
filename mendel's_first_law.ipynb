# %%
heterozygous = 17
homozygous_recessive = 23
homozygous_dominant = 24
x = heterozygous
y = homozygous_recessive
z = homozygous_dominant
T = x + y + z

prob_dominant = 1 - ((y/T * (y-1)/(T-1)) + (0.25 * (x/T * (x-1)/(T-1))) + 0.5 * (x/T * y/(T-1)) + 0.5 * (y/T * x/(T-1)))

print(prob_dominant)
# Out:
# 0.7606646825396826
