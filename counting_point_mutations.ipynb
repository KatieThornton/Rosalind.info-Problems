# %%
x = "..."
y = "..."
def hamming_distance (x,y):
    distance = 0
    for char_x, char_y in zip(x, y):
        if char_x != char_y:
            distance +=1
    return distance

# %%
print (hamming_distance(x, y))
# Out:
# 437
