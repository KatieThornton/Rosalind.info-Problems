# %%
#work out probability of each pair having dominant offspring using punnett cross 
# a = AA-AA 100% dominant 
# b = AA-Aa 100% dominant 
# c = AA-aa 100% dominant 
# d = Aa-Aa 75% dominant 
# e = Aa-aa 50% dominant 
# f = aa-aa 0% dominant

# %%
#create variables for number of pairs of each genotype 
a=16341 
b=19936
c=18900 
d=17105
e=17027 
f=17216

# %%
#calculate expected value 
expected_value = 2*(a+b+c+0.75*d+0.5*e)
print(expected_value)
# Out:
# 149758.5
