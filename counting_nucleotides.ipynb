# %%
s = '...'

# %%
a_count = 0
c_count = 0
g_count = 0
t_count = 0

# %%
for nucleotide in s:
    if nucleotide == 'A':
        a_count += 1
    elif nucleotide == 'C':
        c_count += 1
    elif nucleotide == 'G':
        g_count += 1
    elif nucleotide == 'T':
        t_count += 1

# %%
print(a_count, c_count, g_count, t_count)
# Out:
# 219 182 210 201
