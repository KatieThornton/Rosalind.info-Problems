# %%
s = "..."

t = "CGTAGCGCG"

locations =[]

for i in range(0, len(s)):
    if s[i : i + len(t)] == t:
        locations.append(i+1)
print (" ".join(map(str, locations)))
# Out:
# 39 57 64 71 116 123 149 166 173 195 224 231 342 443 472 489 532 539 598 623 670 677 730 782 789 807 854 864
